# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import *

# %%
path = Path('/data/expressions')

# %%
folder = "anger"
file = 'urls_anger.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest,max_pics=200)

# %%
folder = "happy"
file = 'urls_happy.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest,max_pics=200)

# %%
folder = "sad"
file = 'urls_sad.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest,max_pics=200)

# %%
folder = "surprise"
file = 'urls_surprise.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest,max_pics=200)

# %%
folder = "laugh"
file = 'urls_laugh.txt'
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(path/file, dest,max_pics=200)

# %%
classes = ['anger', 'happy', 'sad', 'surprise', 'laugh']

# %%
for i in classes:
  verify_images(path/i, delete=True, max_size=500)

# %% [markdown]
# # **ImageDataBunch**

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train='.', valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3658: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# ...

# %%
data.classes
# Out:
# ['anger', 'happy', 'laugh', 'sad', 'surprise']

# %%
data.show_batch(rows=5, figsize=(7,8))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3658: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3658: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %% [markdown]
# # **Train model**

# %%
learn = cnn_learner(data, models.resnet34,metrics=error_rate)
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.549815</td>
#       <td>1.792515</td>
#       <td>0.625000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.152883</td>
#       <td>1.848546</td>
#       <td>0.607143</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.878071</td>
#       <td>1.850324</td>
#       <td>0.616071</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.681642</td>
#       <td>1.810024</td>
#       <td>0.616071</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3658: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Learner(data=ImageDataBunch;
#
# Train: LabelList (448 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# sad,sad,sad,sad,sad
# Path: /data/expressions;
#
# Valid: LabelList (112 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# surprise,surprise,anger,laugh,surprise
# Path: /data/expressions;
#
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [12/15 01:25<00:21]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.198332</td>
#       <td>1.795518</td>
#       <td>0.562500</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.146000</td>
#       <td>1.830668</td>
#       <td>0.598214</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-2')

# %% [markdown]
# # **Interpretation**

# %%
learn.load('stage-2')
intp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3658: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# ...

# %%
intp.plot_confusion_matrix()

# %%
learn.export()

# %% [markdown]
# # **Inferences**
# Now to predict expression

# %%
img = open_image('/download.jpg')
img
# Out:
# Image (3, 183, 275)

# %%
learn = load_learner(path)
pred, index, output = learn.predict(img)
pred.obj
# Out:
# 'laugh'
